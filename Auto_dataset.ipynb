# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/home/Downloads/auto_data.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df['horsepower'] =pd.to_numeric(df['horsepower'],errors='coerce')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ## Represent Corelation between variables

# %%
df.corr()
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_7456\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
# origin        0.563450  -0.562543     -0.609409   -0.455171 -0.581024
#
# ...

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_7456\2192395206.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
# <Axes: >

# %% [markdown]
# ## plot different kinds of graphs for mean value represetation ?

# %%
mean_values = df[['cylinders', 'origin']].mean()


mean_values.plot(kind='bar')
plt.title('Mean Values for Cylinders and Origin')
plt.ylabel('Mean Value')
plt.show()

# %%
variables = ['mpg', 'displacement', 'weight']

plt.figure(figsize=(10, 6))
sns.boxplot(data=df[variables],)
plt.title('Box Plot of Selected Variables')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Draw the pair plot using sns for mpg, weight,orign and with hue origin, set the size to 4 ?

# %%
sns.pairplot(df[['mpg','weight','origin']],hue='origin',size=4)
# Out:
# C:\Users\home\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## identify name where acceleration is greater than 15 and horsepower less than 170

# %%
filtered_df = df[(df['acceleration'] > 15) & (df['horsepower'] < 170)]
names = filtered_df['name']
print(names)
# Out:
# 15                  plymouth duster
# 16                       amc hornet
# 17                    ford maverick
# 19     volkswagen 1131 deluxe sedan
# 20                      peugeot 504
#                    ...
# 392                chevrolet camaro
# 393                 ford mustang gl
# 394                       vw pickup
# 396                     ford ranger
# 397                      chevy s-10
# Name: name, Length: 211, dtype: object

# %% [markdown]
# ## Identify how many types of  cylinder vehicles you have ?

# %%
x=df.groupby('cylinders')['name'].nunique()
x
# Out:
# cylinders
# 3      4
# 4    161
# 5      3
# 6     63
# 8     82
# Name: name, dtype: int64

# %% [markdown]
# ## how many vehicles in every  model_year ?

# %%
year_counts = df['model_year'].value_counts()
result_df = pd.DataFrame({'Model Year': year_counts.index, 'Number of Vehicles': year_counts.values})
result_df
# Out:
#     Model Year  Number of Vehicles
# 0           73                  40
# 1           78                  36
# 2           76                  34
# 3           82                  31
# 4           75                  30
# 5           70                  29
# 6           79                  29
# 7           80                  29
# 8           81                  29
# 9           71                  28
# 10          72                  28
# 11          77                  28
# 12          74                  27
