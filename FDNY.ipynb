# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/admin/Downloads/14.FDNY.csv")
df
# Out:
#                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FacilityName     219 non-null    object
#  1   FacilityAddress  219 non-null    object
#  2   Borough          219 non-null    object
# dtypes: object(3)
# memory usage: 5.3+ KB

# %%
df.head()
# Out:
#                                         FacilityName       FacilityAddress  \
# 0                                       FacilityName       FacilityAddress
# 1                                 Engine 4/Ladder 15       42 South Street
# 2                                Engine 10/Ladder 10    124 Liberty Street
# 3                                           Engine 6     49 Beekman Street
# 4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...  100-104 Duane Street
#
#      Borough
# 0    Borough
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
df=df.iloc[1:]
df
# Out:
#                                           FacilityName  \
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                                             Ladder 8
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# 5       14 North Moore Street      Manhattan
# ...

# %%
df
# Out:
#                                           FacilityName  \
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                                             Ladder 8
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# 5       14 North Moore Street      Manhattan
# ...

# %%
df.describe()
# Out:
#               FacilityName  FacilityAddress   Borough
# count                  218              218       218
# unique                 218              218         5
# top     Engine 4/Ladder 15  42 South Street  Brooklyn
# freq                     1                1        66

# %%
df.columns
# Out:
# Index(['FacilityName', 'FacilityAddress', 'Borough'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=1, stop=219, step=1)

# %%
# Total number of fire department facilites in New York city

# %%
df.dtypes
# Out:
# FacilityName       object
# FacilityAddress    object
# Borough            object
# dtype: object

# %%
# Total number of fire department facilites in each borough
data=df.groupby('Borough')
data.count()
# Out:
#                FacilityName  FacilityAddress
# Borough
# Bronx                    34               34
# Brooklyn                 66               66
# Manhattan                48               48
# Queens                   50               50
# Staten Island            20               20

# %%
data.describe()
# Out:
#               FacilityName         \
#                      count unique
# Borough
# Bronx                   34     34
# Brooklyn                66     66
# Manhattan               48     48
# Queens                  50     50
# Staten Island           20     20
#
#                                                                        \
#                                                              top freq
# Borough
# Bronx                           Engine 60/Ladder 17/Battalion 14    1
# Brooklyn       Engine 207/Ladder 110/Battalion 31/Division 11...    1
# Manhattan                                     Engine 4/Ladder 15    1
# Queens                                     Engine 258/Ladder 115    1
# Staten Island                                           Marine 9    1
#
#               FacilityAddress
#                         count unique                          top freq
# Borough
# Bronx                      34     34        341 East 143rd Street    1
# ...

# %%
#Total number of fire department facilites in Manhattan
data1=df["Borough"]=="Manhattan"
data1
# Out:
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
#        ...
# 214    False
# 215    False
# 216    False
# 217    False
# 218    False
# Name: Borough, Length: 218, dtype: bool

# %%
data.describe()
# Out:
#               FacilityName         \
#                      count unique
# Borough
# Bronx                   34     34
# Brooklyn                66     66
# Manhattan               48     48
# Queens                  50     50
# Staten Island           20     20
#
#                                                                        \
#                                                              top freq
# Borough
# Bronx                           Engine 60/Ladder 17/Battalion 14    1
# Brooklyn       Engine 207/Ladder 110/Battalion 31/Division 11...    1
# Manhattan                                     Engine 4/Ladder 15    1
# Queens                                     Engine 258/Ladder 115    1
# Staten Island                                           Marine 9    1
#
#               FacilityAddress
#                         count unique                          top freq
# Borough
# Bronx                      34     34        341 East 143rd Street    1
# ...
