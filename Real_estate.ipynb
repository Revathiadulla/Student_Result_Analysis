# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:/Users/admin/Downloads/12.real state.csv")
data
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
data.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ## City wise list all the Villa which is not less than ten thousand

# %%
villa_list = data[(data['type'] == 'Villa') & (data['price'] >= 10000)]
print(villa_list)
villa_list_by_city = data.groupby('city',group_keys=False)['street'].apply(list)
print(villa_list_by_city)
# Out:
# Empty DataFrame
# Columns: [street, city, zip, state, beds, baths, sq__ft, type, sale_date, price, latitude, longitude]
# Index: []
# city
# ANTELOPE           [3828 BLACKFOOT WAY, 5708 RIDGEPOINT DR, 4844 ...
# AUBURN             [1740 HIGH ST, 2231 COUNTRY VILLA CT, 220 OLD ...
# CAMERON PARK       [2778 KAWEAH CT, 3361 BOW MAR CT, 3429 FERNBRO...
# CARMICHAEL         [5332 SANDSTONE ST, 5907 ELLERSLEE DR, 4010 AL...
# CITRUS HEIGHTS     [6236 LONGFORD DR Unit 1, 6118 STONEHAND AVE, ...
# COOL                                           [2341 BIG STRIKE TRL]
# DIAMOND SPRINGS                                   [636 CRESTVIEW DR]
# EL DORADO                   [4885 SUMMIT VIEW DR, 6320 EL DORADO ST]
# EL DORADO HILLS    [3020 RICHARDSON CIR, 6030 PALERMO WAY, 4070 R...
# ELK GROVE          [5201 LAGUNA OAKS DR Unit 140, 5201 LAGUNA OAK...
# ELVERTA            [7944 DOMINION WAY, 2505 RHINE WAY, 7741 MILLD...
# FAIR OAKS          [5333 PRIMROSE DR Unit 19A, 8164 CHENIN BLANC ...
# ...

# %% [markdown]
# ## In GALT city which residential type has more than 800sq__ft.

# %%
residential_data = data[(data['city'] == 'GALT') & (data['sq__ft'] > 800)]
print(residential_data)
# Out:
#                   street  city    zip state  beds  baths  sq__ft         type  \
# 55    1122 WILD POPPY CT  GALT  95632    CA     3      2    1406  Residential
# 61      306 CAMELLIA WAY  GALT  95632    CA     3      2    1130  Residential
# 63            404 6TH ST  GALT  95632    CA     3      1    1479  Residential
# 174   1121 CREEKSIDE WAY  GALT  95632    CA     3      1    1080  Residential
# 189      840 TRANQUIL LN  GALT  95632    CA     3      2    1266  Residential
# 281        993 MANTON CT  GALT  95632    CA     4      3    2307  Residential
# 296    796 BUTTERCUP CIR  GALT  95632    CA     4      2    2159  Residential
# 307      1092 MAUGHAM CT  GALT  95632    CA     5      4    3746  Residential
# 372         201 CARLO CT  GALT  95632    CA     3      2    1080  Residential
# 402  746 MOOSE CREEK WAY  GALT  95632    CA     3      2    1100  Residential
# 409        332 PALIN AVE  GALT  95632    CA     3      2    1204  Residential
# ...

# %% [markdown]
# ## Display their respective details street,sq__ft,sale_date,city.

# %%
residential_details=residential_data[['street','sq__ft','sale_date','city']]
residential_details
# Out:
#                   street  sq__ft                     sale_date  city
# 55    1122 WILD POPPY CT    1406  Wed May 21 00:00:00 EDT 2008  GALT
# 61      306 CAMELLIA WAY    1130  Wed May 21 00:00:00 EDT 2008  GALT
# 63            404 6TH ST    1479  Wed May 21 00:00:00 EDT 2008  GALT
# 174   1121 CREEKSIDE WAY    1080  Tue May 20 00:00:00 EDT 2008  GALT
# 189      840 TRANQUIL LN    1266  Tue May 20 00:00:00 EDT 2008  GALT
# 281        993 MANTON CT    2307  Tue May 20 00:00:00 EDT 2008  GALT
# 296    796 BUTTERCUP CIR    2159  Tue May 20 00:00:00 EDT 2008  GALT
# 307      1092 MAUGHAM CT    3746  Tue May 20 00:00:00 EDT 2008  GALT
# 372         201 CARLO CT    1080  Mon May 19 00:00:00 EDT 2008  GALT
# 402  746 MOOSE CREEK WAY    1100  Mon May 19 00:00:00 EDT 2008  GALT
# 409        332 PALIN AVE    1204  Mon May 19 00:00:00 EDT 2008  GALT
# 439        913 COBDEN CT    1555  Mon May 19 00:00:00 EDT 2008  GALT
# 454      709 CIMMARON CT    1798  Mon May 19 00:00:00 EDT 2008  GALT
# ...

# %% [markdown]
# ## The cheapest Villa in CA. name the city,street and price for the Villa.

# %%
villas_ca = data[(data['type'] == 'villa') & (data['state'] == 'CA')].sort_values(by='price')
cheapest_city = villas_ca['city'].values[0]
cheapest_street = villas_ca['street'].values[0]
cheapest_price = villas_ca['price'].values[0]
print("city : ",cheapest_city)
print("street : ",cheapest_street)
print("price : ",cheapest_price)
# Out:
# city :  SACRAMENTO
# street :  5840 WALERGA RD
# price :  40000

# %% [markdown]
# ## List top 5 residency details which lie in the budget of 60000-120000, an area more than 1450, min bedroom 3 and, min bathroom 2.

# %%
residency=data[(data['price']>=60000)&(data['price']<=120000)& (data['sq__ft']>1450)&(data['beds']>=3)&(data['baths']>=2)]
residency
# Out:
#            street        city    zip state  beds  baths  sq__ft          type  \
# 366  7342 GIGI PL  SACRAMENTO  95828    CA     4      4    1995  Multi-Family
#
#                         sale_date   price   latitude   longitude
# 366  Mon May 19 00:00:00 EDT 2008  120000  38.490704 -121.410176

# %% [markdown]
# ## separate list of residential apartments with more than 2 beds. Also include columns in following order City,Baths,Sq_feet,Price,flat_type,Beds respectively

# %%
apartments=data[(data['type']=='Residential')&(data['beds']>2)]
residential_apartments=apartments[['city','baths','sq__ft','price','type','beds']]
residential_apartments
# Out:
#                 city  baths  sq__ft   price         type  beds
# 1         SACRAMENTO      1    1167   68212  Residential     3
# 6         SACRAMENTO      2    1104   90895  Residential     3
# 7         SACRAMENTO      1    1177   91002  Residential     3
# 9          RIO LINDA      2    1146   98937  Residential     3
# 10        SACRAMENTO      2     909  100309  Residential     3
# ..               ...    ...     ...     ...          ...   ...
# 980       SACRAMENTO      3    2280  232425  Residential     4
# 981       SACRAMENTO      2    1477  234000  Residential     3
# 982   CITRUS HEIGHTS      2    1216  235000  Residential     3
# 983        ELK GROVE      2    1685  235301  Residential     4
# 984  EL DORADO HILLS      2    1362  235738  Residential     3
#
# [715 rows x 6 columns]
